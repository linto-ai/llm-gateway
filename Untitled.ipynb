# %%
from litellm import completion

# Directly specifying your Hugging Face API token
HUGGINGFACE_API_KEY = "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"

response = completion(
  model="huggingface/TheBloke/Vigostral-7B-Chat-GGUF",
  messages=[{"content": "Hello, how are you?", "role": "user"}],
  api_base="https://api-inference.huggingface.co/",
  auth_token=HUGGINGFACE_API_KEY  # Providing the API key directly to the function call
)

print(response)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3/dist-packages/simplejson/__init__.py:525, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
# ...

# %%
from litellm import completion
import os

# Assuming you have already set your HUGGINGFACE_API_KEY in your environment
HUGGINGFACE_API_KEY = os.getenv("HUGGINGFACE_API_KEY")

# Ensuring that the 'model' argument specifies the model's full repository path
response = completion(
  model="huggingface/Mistral-7B-Instruct-v0.2",  # Adjusted the model path format
  messages=[{"content": "Hello, how are you?", "role": "user"}],
  api_base="https://api-inference.huggingface.co/"
)

print(response)
# Out:
# /home/mkeita/.local/lib/python3.10/site-packages/pydantic/_internal/_fields.py:160: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/mkeita/.local/lib/python3.10/site-packages/pydantic/_internal/_fields.py:160: UserWarning: Field "model_info" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ...

# %%
from litellm import completion
import os

# Assuming you have already set your HUGGINGFACE_API_KEY in your environment
HUGGINGFACE_API_KEY = os.getenv("HUGGINGFACE_API_KEY")

# Correctly specifying the model with the 'huggingface/' prefix
response = completion(
  model="huggingface/mistralai/Mistral-7B-Instruct-v0.2",
  messages=[{ "content": "Hello, how are you?", "role": "user"}],
  api_base="https://api-inference.huggingface.co/"
)

print(response)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3/dist-packages/simplejson/__init__.py:525, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
# ...

# %%
from litellm import completion
import os



#os.environ["HUGGINGFACE_API_KEY"] = "huggingface_api_key"
HUGGINGFACE_API_KEY = os.getenv("HUGGINGFACE_API_KEY")


# e.g. Call 'WizardLM/WizardCoder-Python-34B-V1.0' hosted on HF Inference endpoints
response = completion(
  model="mistralai/Mistral-7B-Instruct-v0.2",
  messages=[{ "content": "Hello, how are you?","role": "user"}],
  api_base="https://api-inference.huggingface.co/"
)

print(response)
# Out:
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/litellm/main.py in ?(model, messages, timeout, temperature, top_p, n, stream, stop, max_tokens, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    2184     except Exception as e:
#    2185         ## Map to OpenAI Exception
# -> 2186         raise exception_type(
#    2187             model=model,
#
# ...

# %%
import requests
HUGGINGFACE_API_KEY = os.getenv("HUGGINGFACE_API_KEY")
API_URL = "https://api-inference.huggingface.co/models/tiiuae/falcon-40b"
headers = {"Authorization": f"""Bearer {HUGGINGFACE_API_KEY}"""}

response = requests.post(API_URL, headers=headers, json={"inputs": "Give me an article with more than 20000 characters"})

print(response.json())
# Out:
# {'error': 'The model tiiuae/falcon-40b is too large to be loaded automatically (83GB > 10GB). Please use Spaces (https://huggingface.co/spaces) or Inference Endpoints (https://huggingface.co/inference-endpoints).'}

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model = "tiiuae/falcon-40b"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)
sequences = pipeline(
   "Girafatron is obsessed with giraffes, the most glorious animal on the face of this Earth. Giraftron believes all other animals are irrelevant when compared to the glorious majesty of the giraffe.\nDaniel: Hello, Girafatron!\nGirafatron:",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_falcon.py:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-40b:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
#
# WARNING: You are currently loading Falcon using legacy code contained in the model repository. Falcon has now been fully ported into the Hugging Face transformers library. For the most up-to-date and high-performance version of the Falcon model code, please update to the latest version of transformers and then load the model without the trust_remote_code=True argument.
# ...

# %%
# !pip install accelerate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 KB 13.8 MB/s eta 0:00:00
# ...
